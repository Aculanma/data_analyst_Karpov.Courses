# %% [markdown]
# # BOOTSTRAP КАК МЕТОД ПРОВЕРКИ СТАТИСТИЧЕСКИХ ГИПОТЕЗ

# %% [markdown]
# ## > Описание эксперимента

# %% [markdown]
# Перед вами таблица с результатами A/B-теста. В числовой колонке показаны значения выручки по каждому пользователю за период эксперимента.

# %% [markdown]
# ## Описание колонок

# %% [markdown]
# - value – значения метрики
# - experimentVariant – Вариант теста (Control – контроль, Treatment – тест)

# %% [markdown]
# ## Задача

# %% [markdown]
# Нужно понять, стали ли мы больше зарабатывать с пользователя или нет. Вы уже знаете о существовании t-теста, U-теста Mann-Whitney и бутстрапа. Открытый вопрос: какой инструмент использовать?
#
# 1. Посчитайте p-value тремя способами: t-тест, U-тест, бутстрап средних
#
# 2. Сравните результат между тестом и контролем по всем этим кейсам
#
# 3. Напишите выводы, которые можно сделать на основе анализа примененных критериев. Напишите, почему мы должны использовать тот или иной инструмент: каких предположений о случайной величине нужно придерживаться, какие условия необходимы и т.п.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import mannwhitneyu
from scipy.stats import ttest_ind
from scipy import stats 
from tqdm.auto import tqdm
from scipy.stats import norm

# %%
AB_df = pd.read_csv("hw_bootstrap.csv", sep=";", decimal=",")

# %%
AB_df
# Out:
#      Unnamed: 0        value experimentVariant
# 0             1    10.380495           Control
# 1             2     9.546867           Control
# 2             3    11.088215           Control
# 3             4    10.147274           Control
# 4             5     9.789808           Control
# ..          ...          ...               ...
# 995         996  1000.000000         Treatment
# 996         997  1200.000000         Treatment
# 997         998  1500.000000         Treatment
# 998         999  2000.000000         Treatment
# 999        1000  3000.000000         Treatment
#
# [1000 rows x 3 columns]

# %%
AB_df.dtypes
# Out:
# Unnamed: 0             int64
# value                float64
# experimentVariant     object
# dtype: object

# %% [markdown]
# Посмотрим на размеры групп:

# %%
AB_df.groupby('experimentVariant').agg({'value': 'count'})
# Out:
#                    value
# experimentVariant
# Control              500
# Treatment            500

# %% [markdown]
# Посмотрим на медиану и средние наших групп:

# %%
AB_df.groupby('experimentVariant').agg({'value': 'median'})
# Out:
#                        value
# experimentVariant
# Control            10.018465
# Treatment          10.025847

# %%
AB_df.groupby('experimentVariant').agg({'value': 'mean'})
# Out:
#                        value
# experimentVariant
# Control            10.026867
# Treatment          27.321499

# %% [markdown]
# Построим боксплоты для наших групп:

# %%
sns.boxplot(x="experimentVariant", y="value", data=AB_df)
# Out:
# <AxesSubplot:xlabel='experimentVariant', ylabel='value'>

# %% [markdown]
# Данный боксплот показывает наличие выбросов в *тестовой* группе.

# %% [markdown]
# Посмотрим на распределение наших групп:

# %% [markdown]
# •*Распределение в контрольной группе*:

# %%
sns.distplot(AB_df[AB_df.experimentVariant == 'Control'].value, kde=False)
# Out:
# C:\Users\DNS\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='value'>

# %% [markdown]
# •*Распределение в тестовой группе:*

# %%
sns.distplot(AB_df[AB_df.experimentVariant == 'Treatment'].value, kde=False)
# Out:
# <AxesSubplot:xlabel='value'>

# %% [markdown]
# •*Та же проверка без выбросов:*

# %% [markdown]
# Отсечем выбросы на уровне value<50:

# %%
sns.distplot(AB_df[AB_df.experimentVariant == 'Treatment'].query("value < 50").value, kde=False)
# Out:
# <AxesSubplot:xlabel='value'>

# %% [markdown]
# Контрольная группа довольно схожа с нормальным распределением, тестовая же, как и ожидалось из боксплота, имеет вот такой вид, где много небольших и схожих по значению наблюдений и какое-то количество выбросов.
# Тестовая без выбросов имеет схожее с нормальным распределение.

# %% [markdown]
# __Проведем t-тест:__

# %% [markdown]
# Требованием для проверки теста является соблюдение гомогенности дисперсий и нормальность данных обеих групп. На практике t-тест может быть использован для сравнения средних и при ненормальном распределении, особенно на больших выборках и если в данных нет заметных выбросов.

# %% [markdown]
# Выполним проверки на эти требования:

# %%
pv_cont = stats.shapiro(AB_df[AB_df.experimentVariant == 'Control'].value)
print(f'Уровень значимости p-value = {round(pv_cont[1],3)}')
# Out:
# Уровень значимости p-value = 0.224

# %%
pv_test = stats.shapiro(AB_df[AB_df.experimentVariant == 'Treatment'].value)
print(f'Уровень значимости p-value = {pv_test[1]}')
# Out:
# Уровень значимости p-value = 1.0930128021733573e-43

# %%
pv_test_filtered = stats.shapiro(AB_df[AB_df.experimentVariant == 'Treatment'].query("value < 50").value)
print(f'Уровень значимости p-value = {round(pv_test_filtered[1],3)}')
# Out:
# Уровень значимости p-value = 0.172

# %%
f_test = stats.f_oneway(AB_df[AB_df.experimentVariant == 'Treatment'].value, AB_df[AB_df.experimentVariant == 'Control'].value)
print(f'Уровень значимости p-value = {round(f_test[1],3)}')
# Out:
# Уровень значимости p-value = 0.038

# %%
f_test_filtered = stats.f_oneway(AB_df[AB_df.experimentVariant == 'Treatment'].query("value < 50").value, AB_df[AB_df.experimentVariant == 'Control'].value)
print(f'Уровень значимости p-value = {round(f_test_filtered[1],3)}')
# Out:
# Уровень значимости p-value = 0.934

# %% [markdown]
# __Тезисно:__

# %% [markdown]
# • Данные результаты говорят следующее:
#     - контрольная группа имеет нормальное распределение;
#     - тестовая группа имеет ненормальное распределение;
#     - тестовая группа без выбросов имеет нормальное распределение;
#     - дисперсии контрольной и тестовой групп статистически различаются;
#     - дисперсии контрольной и тестовой групп без выбросов статистически не различаются.
#
# *Всё выше справедливо, если принимаем за критический уровень α=0.05.

# %%
t_test = ttest_ind(AB_df[AB_df.experimentVariant == 'Treatment'].value, 
             AB_df[AB_df.experimentVariant == 'Control'].value)
print(f'P-value = {round(t_test[1],3)}.')
# Out:
# P-value = 0.038.

# %% [markdown]
# Без выбросов:

# %%
t_test_filtered = ttest_ind(AB_df[AB_df.experimentVariant == 'Treatment'].query("value < 50").value, 
             AB_df[AB_df.experimentVariant == 'Control'].value)
print(f'P-value = {round(t_test_filtered[1],3)}.')
# Out:
# P-value = 0.934.

# %% [markdown]
# __Результаты:__
# • полученные результаты подтверждают тот факт, что t-тест чувствителен к заметным выбросам - наличие выбросов в тестовой группе показало статистически значимые различия меж группами при критическом уровне α=0.05. Стоило убрать выбросы и мы получаем обратную картину;
# • решением убрать для t-теста группы treatment значения value меньше 50 послужило то, что большая доля наших наблюдений были сосредоточены ближе к значению равному 10, а наблюдений сильно превышающих было незначительно;
# • сделаем предположение о том, что статзначимых различий меж группами нет.

# %% [markdown]
# __Проведем U-тест Mann-Whitney:__

# %%
mw_test = mannwhitneyu(AB_df[AB_df.experimentVariant == 'Treatment'].value, 
             AB_df[AB_df.experimentVariant == 'Control'].value)
print(f'P-value = {round(mw_test[1],3)}.')
# Out:
# P-value = 0.859.

# %% [markdown]
# __Результаты:__
# • данный тест менее чувствителен к экстремальным отклонениям от нормальности и наличию выбросов, как итог - различий нету.

# %% [markdown]
# __Проведем бутстрап:__

# %%
def get_bootstrap(
    data_column_1, # числовые значения первой выборки
    data_column_2, # числовые значения второй выборки
    boot_it = 1000, # количество бутстрэп-подвыборок
    statistic = np.mean, # интересующая нас статистика
    bootstrap_conf_level = 0.95 # уровень значимости
):
    boot_data = []
    for i in tqdm(range(boot_it)): # извлекаем подвыборки
        samples_1 = data_column_1.sample(
            len(data_column_1), 
            replace = True # параметр возвращения
        ).values
        
        samples_2 = data_column_2.sample(
            len(data_column_1), 
            replace = True
        ).values
        
        boot_data.append(statistic(samples_1)-statistic(samples_2)) # mean() - применяем статистику
        
    pd_boot_data = pd.DataFrame(boot_data)
        
    left_quant = (1 - bootstrap_conf_level)/2
    right_quant = 1 - (1 - bootstrap_conf_level) / 2
    quants = pd_boot_data.quantile([left_quant, right_quant])
        
    p_1 = norm.cdf(
        x = 0, 
        loc = np.mean(boot_data), 
        scale = np.std(boot_data)
    )
    p_2 = norm.cdf(
        x = 0, 
        loc = -np.mean(boot_data), 
        scale = np.std(boot_data)
    )
    p_value = min(p_1, p_2) * 2
        
    # Визуализация
    _, _, bars = plt.hist(pd_boot_data[0], bins = 50)
    for bar in bars:
        if bar.get_x() <= quants.iloc[0][0] or bar.get_x() >= quants.iloc[1][0]:
            bar.set_facecolor('red')
        else: 
            bar.set_facecolor('grey')
            bar.set_edgecolor('black')
    
    plt.style.use('ggplot')
    plt.vlines(quants,ymin=0,ymax=50,linestyle='--')
    plt.xlabel('boot_data')
    plt.ylabel('frequency')
    plt.title("Histogram of boot_data")
    plt.show()
       
    return {"boot_data": boot_data, 
            "quants": quants, 
            "p_value": p_value}

# %% [markdown]
# Проведем сравнение двух групп:

# %%
get_bootstrap(
    AB_df[AB_df.experimentVariant == 'Treatment'].value, # числовые значения первой выборки
    AB_df[AB_df.experimentVariant == 'Control'].value, # числовые значения второй выборки
    boot_it = 1000, # количество бутстрэп-подвыборок
    statistic = np.mean, # интересующая нас статистика
    bootstrap_conf_level = 0.95 # уровень значимости
             )
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# {'boot_data': [13.91433725618158,
#   21.263849480543804,
#   22.58400892513719,
#   21.721627707396234,
#   7.951268370414642,
#   2.3147815822404407,
#   11.87305981523418,
#   22.333145941338877,
#   18.847821357410815,
#   19.299269246896415,
#   14.199678327194674,
#   33.286350869288526,
#   18.729376174813012,
#   8.782148293455649,
#   35.12689700918749,
#   15.827326361170607,
#   18.67745223252845,
#   34.27496570525909,
#   27.81092350875084,
#   25.02865763436046,
#   14.767136453213732,
#   38.471068157321916,
#   37.90712323613704,
#   19.870651210537865,
#   10.462052701383715,
#   6.655084017965839,
#   5.930072475961744,
#   6.372299655109408,
#   33.599656705002936,
#   19.623763408812742,
#   35.80829732689044,
#   12.277175515166995,
#   32.207195258261926,
#   9.9362501108845,
#   23.855158808987284,
#   31.775576265397287,
#   17.37495318094577,
#   8.307529111806598,
#   32.354197436523876,
#   14.347090521966646,
#   6.050519254936729,
#   12.285798520679656,
#   4.91234826201163,
#   9.398869761042668,
#   7.067342471400451,
#   3.9504032828999662,
#   28.131158557661095,
#   21.01689546760663,
#   9.942396716467059,
#   16.920483885021476,
#   6.992968481755012,
#   24.32234670016566,
#   11.398184952213951,
#   14.758677479752116,
#   8.325913880916861,
#   5.988699318059883,
#   3.8815049254747294,
#   4.295930948786237,
#   18.90731324327711,
#   32.57597200190855,
#   15.383449903567932,
#   13.834493085139087,
#   25.90362358552725,
#   8.26486454038762,
#   9.650655205404217,
#   17.0950415587932,
#   7.926138878795314,
#   31.09371921895871,
#   14.278844849908356,
#   24.351335815252057,
#   19.62546623724981,
#   8.897779660365154,
#   30.24819015408496,
#   14.937843931827743,
#   16.228002173668365,
#   14.905301585698627,
#   19.452388913315882,
#   15.043692341895442,
#   22.649139888980265,
#   16.896127741575953,
#   21.977459521043606,
#   25.624767665496805,
#   2.463985820600911,
#   14.918232771718703,
#   37.50802703406707,
#   24.974444158936464,
#   21.36952263223933,
#   24.866811196370435,
#   10.441411310187261,
#   12.38019147428683,
#   27.854317408664347,
#   14.977800317177831,
#   19.035356080665736,
#   14.30628889970319,
#   6.398306001143503,
#   24.915468412245637,
#   27.253628015491078,
#   24.62732266753764,
#   20.360052457378305,
#   5.945439528489006,
#   23.29493326460875,
#   35.13529573680089,
#   39.80368055980597,
#   16.895455137834702,
#   13.509680214575058,
#   25.680799304355126,
#   10.953804782524307,
#   16.005796693170005,
#   4.371042476306972,
#   13.263188693008813,
#   28.255086712766282,
#   2.0042132403153943,
#   23.150548933333425,
#   19.914104826138118,
#   21.22768223856668,
#   12.918564147169917,
#   10.361411292945162,
#   20.807527585362706,
#   10.31337212246089,
#   24.642342994033964,
#   18.892361388060948,
#   29.129245432250997,
#   25.25181722445982,
#   33.90028704009224,
#   33.22393897397616,
#   14.883065371331597,
#   16.354756814384896,
#   11.25498094374231,
#   13.66131956783529,
#   10.917772458064618,
#   26.70628957654796,
#   36.251246667286246,
#   4.480155605929427,
#   25.817676917217973,
#   26.24268791799497,
#   8.970546186778138,
#   20.26329909952129,
#   11.926009116926476,
#   8.26172305286593,
#   38.67287591903581,
#   -0.019559915535307226,
#   53.53578235812335,
#   6.4157996077996895,
#   18.895858634121474,
#   21.178770048650048,
#   16.873086694620735,
#   11.91098450460652,
#   23.920597884869068,
#   7.902724860465506,
#   15.004938613189886,
#   15.325931284056532,
#   17.283180292719837,
#   18.908418954820895,
#   33.8145965779739,
#   22.693877855146077,
#   14.713441735061904,
#   33.24443777525127,
#   19.902863104459286,
#   22.858355239656618,
#   27.57882788278349,
#   19.90090542745635,
#   10.91119794595689,
#   16.810484044080255,
#   22.07257896706296,
#   21.688844069015623,
#   4.012683463306271,
#   8.80139197242579,
#   11.800891221811867,
#   20.39543700316579,
#   10.290727104763048,
#   21.056235799754884,
#   25.86325208777789,
#   7.89257680966557,
#   9.291588958066995,
#   13.909484079567989,
#   18.876184473045342,
#   8.248537042296968,
#   35.36750483645763,
#   25.785956373944476,
#   17.278360571681368,
#   24.796204328332003,
#   28.10930707347542,
#   9.980954707199796,
#   20.195859901016902,
#   3.987579376404547,
#   15.318296619648297,
#   14.86978062907058,
#   13.365343908295463,
#   30.666519683679,
#   5.858751811642373,
#   -0.07170481566201126,
#   12.005191845172732,
#   20.943425490633736,
#   25.727602239248917,
#   29.360819161804656,
#   11.93011482066458,
#   21.342692988459937,
#   13.62385350084986,
#   3.015886230028192,
#   30.82777447767276,
#   31.253351398876916,
#   20.349370090594,
#   7.918711976478052,
#   22.55275741438117,
#   13.912591956490617,
#   10.959427639694338,
#   32.61772310936324,
#   13.258944132422265,
#   6.8729441256423165,
#   17.008065443178538,
#   5.997695930465984,
#   26.68348381534674,
#   11.892825626217679,
#   16.040924079501508,
#   27.098745762840178,
#   11.212707054286465,
#   23.210677201078727,
#   14.670274206245455,
#   12.250888966482009,
#   10.859310274741793,
#   4.947461746795925,
#   8.980663389007345,
#   8.362545597992106,
#   17.431963103431386,
#   18.044872807204268,
#   11.678342929205794,
#   21.665075815923252,
#   9.480603539032847,
#   10.71639863954791,
#   26.69098835726553,
#   16.591807650662382,
#   17.871447029396162,
#   6.385709523127554,
#   18.955960707289037,
#   16.477490133692562,
#   10.798901340150202,
#   50.81861715509427,
#   30.280915582598688,
#   23.414685251889576,
#   10.884432012235598,
#   12.29395233303847,
#   24.72580515980699,
#   19.984718100888294,
#   28.128227788300208,
#   15.147395867952183,
#   26.80529130774094,
#   27.671191236551806,
#   20.73808185293446,
#   28.02015418139657,
#   40.22636123787363,
#   26.146281530832667,
#   31.999445522519657,
#   6.379386609040509,
#   25.287266111423026,
#   23.184675911798152,
#   23.357105070092032,
#   18.101001870792807,
#   7.244286648797917,
#   6.9718745656220165,
#   16.361712444889015,
#   15.702985195686706,
#   25.244625813365708,
#   28.30074236095418,
#   6.028224675531108,
#   24.727742068664128,
#   19.796768441971903,
#   16.64321145935292,
#   7.917928094510472,
#   15.855454934716505,
#   15.877894436906548,
#   6.774411137097909,
#   11.972307203009883,
#   17.65040211537558,
#   15.383560599850773,
#   12.183784310523642,
#   11.362343624912231,
#   13.264955462219264,
#   22.65831832921478,
#   20.277011210491402,
#   28.639638926994895,
#   8.927009634400255,
#   25.897955450322655,
#   13.886988657821895,
#   5.898219720411447,
#   13.65945154929227,
#   19.308797737833157,
#   19.63589496354651,
#   10.816699218896932,
#   19.01525334852397,
#   10.190117017907214,
#   16.337534228082035,
#   6.042464601895672,
#   16.748011119769828,
#   12.316614812556699,
#   21.318494382438274,
#   26.699317447971886,
#   20.255877336217438,
#   18.94847623723751,
#   9.848691460149057,
#   27.888056145239702,
#   19.24705574953836,
#   18.85843252360535,
#   12.431214239335185,
#   8.037994017770545,
#   34.13111719231744,
#   20.292374753374588,
#   14.706404217192096,
#   18.347712091782668,
#   17.032010156068253,
#   19.29395235962825,
#   22.894512843959973,
#   22.247672845185182,
#   13.88083263538361,
#   21.28600915062937,
#   11.726332223948118,
#   7.868907398203294,
#   25.643525830559575,
#   44.02623765019493,
#   14.879478973961275,
#   8.908413050136149,
#   7.430313484485449,
#   24.248581612287843,
#   13.653749828069493,
#   14.318649772656128,
#   8.913972064745082,
#   23.279009862420384,
#   11.031093630794345,
#   19.643861378130985,
#   20.23833784355406,
#   26.84514739198178,
#   19.239641166885015,
#   31.6368956928781,
#   6.014602746842142,
#   14.886995817890146,
#   13.186594457855966,
#   6.877779310428309,
#   6.26753278711802,
#   20.3058591274879,
#   22.198843516029253,
#   16.253778125647635,
#   15.236778616549184,
#   19.235890496690914,
#   20.105385109306475,
#   25.340999566023,
#   18.247225413493645,
#   20.08369521748137,
#   14.323838220631199,
#   11.965612983625439,
#   20.23209599443163,
#   14.452526599104454,
#   33.1962239527005,
#   31.75643681621868,
#   18.714395714806663,
#   21.803702341878196,
#   22.811667162472453,
#   12.962149795806916,
#   22.65228933182219,
#   25.218331857224754,
#   27.875833056473788,
#   13.87175345498986,
#   21.860803455020815,
#   13.207929676729186,
#   11.878414484543306,
#   5.32758744593548,
#   26.26285262841818,
#   9.92769087589563,
#   31.13652543810198,
#   30.107454215352575,
#   39.608376817278334,
#   39.88117142290926,
#   11.974391256852401,
#   15.0211497861935,
#   12.447317687687327,
#   13.941049331799881,
#   10.262212569405577,
#   35.651825911566625,
#   14.921701936768992,
#   19.012869437055887,
#   39.62774594601555,
#   31.85579414649511,
#   10.32192414228394,
#   22.786322491237428,
#   12.815847055231059,
#   4.944653304684158,
#   5.3944288321126415,
#   16.28909311336318,
#   4.976314752949511,
#   16.804126346781548,
#   14.859422204023847,
#   4.479440712883674,
#   28.793078089991397,
#   30.460302452934297,
#   11.99113299640876,
#   18.867367659871732,
#   11.871470006832354,
#   5.967706396200182,
#   4.935892060704635,
#   17.82300639943916,
#   16.7341132160753,
#   17.985773809157237,
#   20.2912533584268,
#   19.14391394115885,
#   8.276889439132667,
#   22.61188603109496,
#   14.907907998888128,
#   17.153878342605193,
#   25.14770869317417,
#   32.78309809524981,
#   9.278116022479532,
#   18.28284826429271,
#   26.275892930529423,
#   23.009658062399225,
#   15.412591256753668,
#   10.63740602317679,
#   4.810918655132893,
#   2.0530740819231355,
#   19.895519222089376,
#   26.29317072018935,
#   15.182904372722554,
#   26.20773431799683,
#   20.899987134447613,
#   14.733849270237034,
#   19.654334897415893,
#   20.324965710804694,
#   10.794907859943152,
#   25.31177643648901,
#   36.279515685005265,
#   14.069136151415222,
#   23.682281509556024,
#   7.884629862459594,
#   6.984615576135681,
#   9.499506821904355,
#   34.32363069120491,
#   15.895852003439662,
#   34.78408997387289,
#   18.285651212916427,
#   24.192358494356412,
#   15.772731912105742,
#   17.319960086640464,
#   14.278089106909501,
#   23.70676034942226,
#   28.8374973193947,
#   17.257931333321466,
#   11.95753750572487,
#   14.456680910198216,
#   29.685599064278385,
#   17.811928948901993,
#   14.320382857058247,
#   17.96674559575549,
#   22.963439985437645,
#   17.313254191349085,
#   10.022879024545535,
#   22.656681192506234,
#   20.242828118101073,
#   17.887662178743383,
#   16.249819318296424,
#   13.83112215513342,
#   15.947179397113615,
#   13.358912695638544,
#   4.7415505643968245,
#   20.93328489497795,
#   13.775832842990575,
#   29.975449163940574,
#   16.31282860158051,
#   12.751473814956102,
#   20.2050669154179,
#   26.88626308413988,
#   15.602211598301073,
#   15.090884800338438,
#   6.899037432784381,
#   24.7967107100882,
#   17.84595541717136,
#   26.86663138004669,
#   17.633968813496914,
#   12.877908738546436,
#   15.851226892345023,
#   18.267714416235506,
#   17.193350200744554,
#   24.873352330108297,
#   21.568474117676544,
#   16.38576306236461,
#   7.942339878280627,
#   20.372910392228768,
#   12.365145448301488,
#   10.447395698616047,
#   17.333228361309704,
#   11.31646440467227,
#   5.32810794577934,
#   17.940311706667398,
#   11.043315276618923,
#   6.0047173564994605,
#   34.97787140007927,
#   18.005853590802907,
#   9.796440746980382,
#   14.737092622651094,
#   8.87930936394824,
#   15.170307678235668,
#   9.845117871146158,
#   29.253897857517224,
#   11.427406791333354,
#   7.957904633860128,
#   21.813995480761687,
#   15.677184281268852,
#   10.288428193488777,
#   15.902341894994713,
#   7.35497232099876,
#   25.27920741942264,
#   30.613328547257584,
#   11.603479849868217,
#   8.000303915726741,
#   26.278232539749702,
#   10.252567841340134,
#   25.846221770205844,
#   27.21866962915064,
#   23.68454940905626,
#   36.27857056595863,
#   16.82305986516512,
#   31.77433384511024,
#   22.64429267450965,
#   8.839404732970324,
#   11.89413387350024,
#   14.266587680105982,
#   19.991147411917606,
#   4.8766692684548545,
#   16.698278816620423,
#   13.24909208181419,
#   21.09798672976695,
#   24.270692118869746,
#   7.351176150931504,
#   19.86714474724988,
#   19.822163543147013,
#   10.694410503034268,
#   24.845379395197998,
#   12.316367933974215,
#   14.001960705522214,
#   19.27726303445116,
#   21.768845158462796,
#   2.93476151999384,
#   8.950242705027657,
#   14.329282591239336,
#   5.96381234345248,
#   20.71172629416488,
#   14.120662540461419,
#   20.189708240580426,
#   26.876584154198195,
#   28.308991448734794,
#   -0.03687252121745921,
#   17.154155778568857,
#   15.92032407711584,
#   11.286205897936574,
#   25.817446397790874,
#   19.369248557774256,
#   12.960424885259048,
#   12.887043745156623,
#   14.63576618140876,
#   14.74952211449095,
#   28.273954890770604,
#   17.96693586938062,
#   14.237132589312724,
#   26.006339642758356,
#   14.90168849503339,
#   14.380399981144071,
#   29.240239911542254,
#   12.016643283257151,
#   20.32649852288737,
#   33.77576352391386,
#   26.835884321609548,
#   6.418818261714723,
#   17.917586007498155,
#   17.382602103052385,
#   26.060395069263464,
#   18.26029748253046,
#   12.340963761262287,
#   28.26210129667447,
#   13.72393063205072,
#   9.30205965345426,
#   15.351563689133444,
#   17.848642990407598,
#   8.431405284648728,
#   9.952472799593922,
#   19.822063013992857,
#   0.13637374438680006,
#   17.01295475386631,
#   11.931126968424898,
#   40.055668371460825,
#   19.321591101944634,
#   24.92798010211761,
#   35.29274813178696,
#   16.932896520170644,
#   25.71847828125445,
#   14.351412192432157,
#   19.138230616999017,
#   16.757690463451937,
#   12.240247186590892,
#   10.709260461407098,
#   15.213127352537379,
#   25.978541053542262,
#   6.313765928528857,
#   6.991015859955111,
#   10.963661489287277,
#   15.975852575443714,
#   21.228854655992187,
#   11.222640555968662,
#   6.080891009203974,
#   24.17322804079454,
#   30.04751790651317,
#   11.946756376606404,
#   17.855925230927483,
#   3.098896671098549,
#   26.272640873095817,
#   11.77666815263566,
#   17.92090581593294,
#   7.932297764678152,
#   7.0115857106887365,
#   17.9410515024528,
#   18.415721894931576,
#   15.809975755298082,
#   26.16501994406731,
#   22.7592785849144,
#   10.318284353589535,
#   10.300452070623264,
#   13.276665421115359,
#   19.808387548936544,
#   31.826823351592147,
#   24.112874664405517,
#   10.352382447423953,
#   22.97044387571711,
#   13.961325983799785,
#   23.845298163088874,
#   22.262828180680465,
#   17.928842473389036,
#   16.687021515389084,
#   11.354406651762414,
#   14.944466688477904,
#   11.773729468700038,
#   18.816598766650664,
#   17.108860952551616,
#   28.586416860586823,
#   16.748660908659787,
#   13.026996474499517,
#   23.839398902166042,
#   20.771653230624246,
#   26.341579777136616,
#   0.023084560491524186,
#   14.282259948218664,
#   14.956424697263735,
#   19.674824407101617,
#   11.957213321530112,
#   11.999734179605818,
#   18.694864236169472,
#   12.904909012247316,
#   13.981520090917464,
#   13.867371734253942,
#   13.354128539105382,
#   8.949402101699429,
#   29.622460875378046,
#   16.32165970628627,
#   40.52461595048988,
#   19.315289367973254,
#   6.024290064472902,
#   24.570335150591397,
#   30.686747318557767,
#   16.290100417584405,
#   20.862864640575545,
#   27.760713702392426,
#   23.334036242936964,
#   29.991388539694622,
#   24.863688479208932,
#   10.902870442930515,
#   10.573933698324717,
#   20.859965295043274,
#   27.907540032379213,
#   33.225042370178414,
#   18.57611455740809,
#   11.327644962329824,
#   13.711819653221673,
#   19.361249930765716,
#   4.942439212006544,
#   4.966813741556441,
#   4.940741368229254,
#   18.314981519872532,
#   19.783761866394364,
#   10.693753708079214,
#   8.634568513654798,
#   6.392316931327153,
#   6.918958689600153,
#   13.975925496803224,
#   24.915767311207667,
#   20.43352343718243,
#   17.67124372477066,
#   16.192957458890405,
#   15.323295553276253,
#   4.865559812508133,
#   24.269871883716966,
#   8.369026571835173,
#   13.320136859763865,
#   26.40486314222163,
#   12.783235918607991,
#   23.348396071100147,
#   12.599617842812746,
#   23.679457512632016,
#   11.246429757069318,
#   20.2727984864501,
#   12.834982477737382,
#   21.345203542231598,
#   7.44618985182378,
#   13.992907558072005,
#   13.387024851774177,
#   18.27375132564271,
#   7.957318485643036,
#   6.413768446343132,
#   25.042549185811986,
#   11.347775709861443,
#   3.9833495492187083,
#   20.667294608329442,
#   11.90686582531188,
#   14.062860741629303,
#   19.29367262987258,
#   6.783347922517267,
#   6.950902777959962,
#   15.995104672098558,
#   23.847581426801682,
#   17.717030263221822,
#   7.890476319153892,
#   17.815061564470348,
#   27.063812881440562,
#   21.217126213017927,
#   20.345112665617314,
#   26.61025475892705,
#   6.836054625497301,
#   28.194926385766266,
#   21.21214303045405,
#   11.379368043550524,
#   20.906032871156626,
#   24.860082879865594,
#   16.207651311521836,
#   24.35277406202615,
#   29.26540667364157,
#   18.85577607472721,
#   13.123858123384126,
#   16.71380255439839,
#   31.19629910960535,
#   19.956976752444923,
#   13.965719450160137,
#   26.40027636233505,
#   20.32897730283564,
#   6.422937153209057,
#   11.913306973787718,
#   21.485421675592335,
#   39.576135891339945,
#   20.148200586975207,
#   8.655553122379933,
#   32.347741947551285,
#   36.94748372477956,
#   12.333403733757157,
#   21.621555595846722,
#   15.932096803111552,
#   22.199004863533265,
#   19.37933823196662,
#   8.694631908568384,
#   36.186742216026126,
#   18.71411986093954,
#   6.8912906771189615,
#   11.350128093846212,
#   31.307982359649912,
#   27.72213883924819,
#   11.89436418075774,
#   4.134664112305018,
#   21.077116332837548,
#   16.044097633644764,
#   17.37295406521448,
#   16.08725527071485,
#   2.9440459822153784,
#   36.2243661276962,
#   30.98047991586417,
#   18.35155034878006,
#   13.731016375125762,
#   14.652121292870802,
#   11.37227574304056,
#   14.966759314765953,
#   22.284907349484985,
#   9.996320379917671,
#   14.863247712593413,
#   18.24135106738315,
#   10.996344744899073,
#   18.415369402875832,
#   15.236420814435157,
#   4.743317808047065,
#   21.590443548134672,
#   16.23064094479647,
#   4.979529183080826,
#   23.235807548295526,
#   14.43776166209829,
#   37.124080057340855,
#   4.924301132243407,
#   18.297262779506017,
#   5.920281594207889,
#   9.30718813497621,
#   2.0239696880239784,
#   20.8761195293945,
#   17.080385136583217,
#   19.855721102386326,
#   12.922800392795391,
#   11.836623930173584,
#   2.488339337522957,
#   12.893887519069402,
#   8.317442829877292,
#   17.792157059416393,
#   15.855702315586978,
#   13.519375896812814,
#   25.242858962345682,
#   5.3960139933289675,
#   20.2708224415528,
#   17.931047434248555,
#   22.302462601767402,
#   24.593837874943375,
#   7.369484309490407,
#   7.002682523650982,
#   17.668141861584843,
#   11.839798206811542,
#   9.72204212898899,
#   12.385258205179554,
#   9.980603086625544,
#   14.297563380371757,
#   31.586307988315717,
#   10.773607048539766,
#   5.034636904551441,
#   15.911000028622272,
#   28.467876711536945,
#   6.089084915762292,
#   19.885450388910456,
#   28.81660676931434,
#   28.85419363349174,
#   17.82350012121224,
#   13.61091555460274,
#   24.786319474442067,
#   7.967326131160272,
#   36.2690836509412,
#   12.284497613596628,
#   33.60724315654495,
#   10.6214922418245,
#   22.9939594620593,
#   26.87342563534999,
#   23.251980851255063,
#   42.01933022440097,
#   11.953611555680595,
#   16.31115150803005,
#   11.392366137350972,
#   20.88809369101615,
#   7.4006612137710945,
#   22.69696548706228,
#   17.678867474839883,
#   11.378208920201889,
#   26.323899419160487,
#   7.81330398325203,
#   22.279977890258408,
#   23.48267925394361,
#   32.21377556672444,
#   10.2754693171781,
#   6.0296139679023995,
#   7.392252845008601,
#   25.055439683053848,
#   14.91195540487856,
#   8.269323399918683,
#   5.9488022143916375,
#   19.212942021632305,
#   16.953214695472752,
#   29.26267742609914,
#   15.907836841440758,
#   25.421060002415118,
#   24.31270519005736,
#   5.906815438777272,
#   8.251525982145145,
#   25.761948432346557,
#   19.804212587477025,
#   18.267664518565084,
#   19.679804080939448,
#   7.302076623802989,
#   29.25054040716892,
#   19.994967389175066,
#   10.928835879693366,
#   8.900970111519289,
#   24.987595152739132,
#   15.412264910257646,
#   18.904160583203605,
#   18.914927179918863,
#   10.346759906679905,
#   21.431418359522773,
#   22.594876055062755,
#   16.176191608009134,
#   19.883530830132834,
#   19.30272585452584,
#   16.714867194698787,
#   2.88206499704285,
#   14.882041112024694,
#   17.072198559926065,
#   2.9969863230613196,
#   6.958185923833636,
#   15.490464991281547,
#   28.187373977657266,
#   11.973375501081684,
#   16.57783196298689,
#   4.074876406550263,
#   11.253487967501021,
#   12.61626005555595,
#   18.295078431338702,
#   19.262883566684543,
#   21.34003868003074,
#   26.836137527172426,
#   16.716438996037112,
#   8.805096207472221,
#   15.943752540359307,
#   20.974407389188357,
#   22.821421966995928,
#   23.06377930570978,
#   10.41317665768411,
#   5.9429767636924495,
#   16.262090910467645,
#   16.228178507021628,
#   31.00201761959115,
#   19.91458668878297,
#   5.300002892602372,
#   7.988106312444144,
#   21.14141647485308,
#   15.052048699619752,
#   15.327260184440462,
#   15.65056258802556,
#   15.996555748382768,
#   23.86134490781503,
#   21.729488030546932,
#   27.00260344153414,
#   17.63469652546571,
#   10.185526975414263,
#   14.348820182706577,
#   17.800969296741957,
#   19.276959921283677,
#   6.77800186362458,
#   14.34893585651039,
#   21.62946245588182,
#   28.874766359472368,
#   22.65209602563556,
#   17.667661738390418,
#   21.29502064140201,
#   16.736853759178008,
#   20.883058958120955,
#   14.250198686026856,
#   8.338266721278154,
#   6.954237217720252,
#   13.291118563073212,
#   19.7946631604554,
#   11.92950551516269,
#   10.898434943498163,
#   26.842053451460167,
#   17.689905635313973,
#   3.9470673736877355,
#   23.731881062904954,
#   29.304436099223963,
#   13.272613878931868,
#   30.822530412215237,
#   15.31574753913175,
#   4.6839186003851765,
#   5.937101578400634,
#   13.837576252347304,
#   14.480481433267427,
#   12.99567721488582,
#   12.336307970262174,
#   19.699679800370603,
#   27.99188861661092,
#   16.04697145707597,
#   9.039707380873692,
#   8.7293162879338,
#   10.942277353983977,
#   10.312518515954903,
#   20.255449672554494,
#   21.054695147228546,
#   12.365899818962077,
#   12.352746793140934,
#   14.300599139933492,
#   4.695593483901423,
#   35.67217225846631,
#   36.84216293917559,
#   6.350132754006253,
#   23.16202974479489,
#   23.6175582351144,
#   25.684648720729264,
#   24.26389762644414,
#   19.76307235695331,
#   24.2983018869303,
#   15.33372153799688,
#   20.656756466514942,
#   53.12790252267067,
#   24.592232049537596,
#   17.93308600290012,
#   10.379034196099125,
#   13.115695084990419,
#   11.321920323441661,
#   23.781957841369618,
#   14.744713360448259,
#   10.78826776504942,
#   22.269183662658428],
#  'quants':                0
#  0.025   4.291899
#  0.975  36.187683,
#  'p_value': 0.03521008718560183}

# %% [markdown]
# Та же проверка без выбросов в тестовой группе:

# %%
get_bootstrap(
    AB_df[AB_df.experimentVariant == 'Treatment'].query("value < 50").value, # числовые значения первой выборки
    AB_df[AB_df.experimentVariant == 'Control'].value, # числовые значения второй выборки
    boot_it = 1000, # количество бутстрэп-подвыборок
    statistic = np.mean, # интересующая нас статистика
    bootstrap_conf_level = 0.95 # уровень значимости
             )
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# {'boot_data': [-0.07122506544912,
#   0.13281700052717227,
#   -0.026310280369804318,
#   0.02797877597033782,
#   0.022415482227621908,
#   0.03604668212100037,
#   -0.09527643765321692,
#   -0.001678068830516466,
#   -0.11585398818415804,
#   -0.04283939624561839,
#   0.031759287329727215,
#   0.038199738542635586,
#   -0.04905043168345813,
#   0.1349065408921888,
#   0.05411746380028859,
#   -0.00570880476085911,
#   0.0803861242899444,
#   -0.0606201294901787,
#   -0.10802653406031482,
#   0.04827297192825952,
#   0.08850029271069815,
#   0.04405683912663072,
#   -0.08799438182376207,
#   0.0017667275280786043,
#   -0.04714899832168129,
#   -0.04304012563423498,
#   -0.10525557877064529,
#   0.036563984761075474,
#   0.0027198833032198166,
#   0.1228881050183297,
#   0.0027633657817514035,
#   0.020859100692740995,
#   0.08242925649154564,
#   -0.13266824737423377,
#   0.00861178767169335,
#   -0.04774881634221373,
#   -0.006161436533695053,
#   -0.08120862482418012,
#   -0.060659715892828814,
#   0.003621744847121633,
#   -0.10460064628765231,
#   0.12941868057440686,
#   -0.037087845224890614,
#   0.12891626193230366,
#   0.16397617007594079,
#   0.05131324633709866,
#   -0.03460646871272566,
#   -0.01715299116681024,
#   -0.002390179150207672,
#   -0.04817324943767787,
#   0.039909985016105765,
#   0.006616188264183975,
#   -0.04422789520007342,
#   0.10818528202262812,
#   -0.0426800091507431,
#   0.0691942364028808,
#   0.050232143551498964,
#   -0.002041071250490134,
#   -0.1564952321517712,
#   0.0929476754211791,
#   -0.05035458158642747,
#   0.032813711294695125,
#   -0.003697464597800959,
#   -0.06430316594158292,
#   0.053069900213706944,
#   -0.00048154670333921956,
#   0.07826518878178845,
#   -0.0802398987561066,
#   -0.15619397123619194,
#   0.06484693329006852,
#   -0.07282561902803941,
#   -0.05691568148679238,
#   -0.012772471857076084,
#   -0.09996430880237384,
#   -0.07207801572915429,
#   -0.03233545148188277,
#   0.029301342729237234,
#   0.040727210437403016,
#   0.16457309476550464,
#   0.1264998235082615,
#   0.08140675961452892,
#   -0.01901235485157926,
#   0.017326346723761432,
#   0.0019131424370950612,
#   -0.022888841611484523,
#   -0.10794429150154805,
#   -0.004139127739334114,
#   0.034790595411081426,
#   -0.010783684813052474,
#   0.053857822548934564,
#   -0.011268901952043109,
#   0.042849762054039786,
#   0.011470024469691253,
#   0.030860194953005404,
#   -0.12596018918718066,
#   0.02534234224159171,
#   -0.08132074942846934,
#   -0.029512172196572095,
#   0.08455933514191827,
#   0.07299952770692997,
#   0.024194521732068708,
#   -0.0712649380026047,
#   -0.043953850925337434,
#   -0.03422594368818643,
#   0.09934338415203037,
#   0.042953831426565614,
#   0.07272052140771379,
#   0.11278633876080946,
#   0.14356837892959184,
#   -0.06606188390413692,
#   -0.1307006205527248,
#   0.018619262097747225,
#   0.006386317029708266,
#   0.03162545902864089,
#   0.0584280691422876,
#   0.02010153206953369,
#   0.032263577619595196,
#   0.011452619945073295,
#   0.0720934139245113,
#   0.025136113157328666,
#   -0.007397308602135055,
#   -0.14692582168174617,
#   0.013292457648049094,
#   -0.03030390954848805,
#   0.10841938088760195,
#   0.01564047992406259,
#   -0.035587530618322205,
#   -0.07144333615017295,
#   -0.0006808914683400502,
#   0.13368759591726942,
#   -0.06788216382738632,
#   3.875302039269002e-05,
#   0.020215991752646545,
#   -0.03405558404187481,
#   -0.04718745172589678,
#   -0.03794231829412986,
#   -0.07995902565010482,
#   0.007653530596021696,
#   0.13985432131242526,
#   0.04021832896217248,
#   -0.0717807505790482,
#   0.03591728843037956,
#   0.02566979667827063,
#   0.01042652009538969,
#   -0.031402264864054175,
#   -0.09114894809763996,
#   0.016344749106796286,
#   -0.05364340331200523,
#   0.01288144247308054,
#   -0.04667795574956912,
#   0.089698693932597,
#   -0.02365446619968914,
#   -0.012582780897275825,
#   -0.04661216473544805,
#   -0.051998354449343864,
#   0.0038848591428060075,
#   0.021568090727249967,
#   -0.13694451564390775,
#   0.031061762894101008,
#   0.053447897395457744,
#   -0.015913956605581703,
#   -0.1221062584092909,
#   0.04842905027075162,
#   0.11387073054476282,
#   -0.05613228324808617,
#   -0.07924270672726763,
#   0.04539987675729762,
#   -0.10918516955663904,
#   0.04555204161384019,
#   -0.03680744320838869,
#   -0.001490940944094632,
#   -0.005244360893025046,
#   0.053261313092148654,
#   -0.110438791277085,
#   0.09666859129842642,
#   -0.11053697784836558,
#   -0.014401158720627194,
#   -0.10947122999801451,
#   -0.08739309577498311,
#   -0.04401238224955506,
#   0.007050818679291027,
#   -0.009121304564182253,
#   0.07095133739345982,
#   -0.12562022131933226,
#   0.028919215231375972,
#   0.05680721895547158,
#   0.012640830837987949,
#   0.1674539258684895,
#   0.09430246080549587,
#   0.11348471763802159,
#   -0.012816871104762484,
#   0.009085346298933317,
#   0.08377096374338144,
#   -0.024873184172038876,
#   -0.1172126329323433,
#   -0.03813409604669715,
#   -0.0849259122728121,
#   0.035225888914837356,
#   -0.08202533304629611,
#   0.11824471981753071,
#   -0.02821985389192605,
#   -0.0034748163657809528,
#   0.0947854752681625,
#   0.04172929955427129,
#   -0.03111534743713662,
#   0.06962531436174935,
#   -0.06574421854982226,
#   -0.007649127137733913,
#   0.021944769134929487,
#   0.012431884196365317,
#   0.013042644232493572,
#   -0.041959712525530435,
#   0.15929656413476678,
#   0.02494367035667011,
#   -0.06865753486901127,
#   -0.05872651017763353,
#   0.04479117978798364,
#   0.02027303750186782,
#   0.07250651586782553,
#   -0.00980467197055468,
#   0.046480224598512976,
#   -0.15393766460934266,
#   0.024365391717770635,
#   -0.08105994640314229,
#   0.0042600983181806384,
#   -0.07234088132573824,
#   -0.08803271478468666,
#   0.06491394366560321,
#   -0.006212854157398695,
#   -0.07776461767316079,
#   -0.04983408592760874,
#   0.060273268239551925,
#   -0.021345008196034243,
#   -0.062432591051694075,
#   -0.037695434501602065,
#   -0.1773161005203594,
#   -0.07597154958028973,
#   0.06403614311156502,
#   -0.008778487653056999,
#   0.06731949862681752,
#   -0.020693112897470556,
#   0.022280313611977576,
#   -0.011649423286808513,
#   -0.06410745073996438,
#   -0.08446853765808093,
#   0.11814184651721149,
#   -0.015240885397911796,
#   0.03255207184100861,
#   -0.008839623082339543,
#   -0.09619223993561832,
#   0.0957160153340979,
#   0.025926453436468933,
#   -0.08536596154283238,
#   0.07861604854262616,
#   0.0440383428236899,
#   0.05243801900815015,
#   0.004338232433882538,
#   0.034519541094612194,
#   -0.005218162599796017,
#   -0.04311983487841431,
#   -0.0264893385103111,
#   0.04557762673992727,
#   0.06753715541886862,
#   0.04944575367646209,
#   -0.03323421780441471,
#   0.004949192741745989,
#   -0.018457552117711273,
#   -0.0070866394447488545,
#   -0.011299429841120201,
#   -0.041281842773177146,
#   -0.018082700457508594,
#   0.0605926081163517,
#   -0.009478430585490472,
#   -0.056522554760089605,
#   0.1024263313027518,
#   -0.006904612627812057,
#   0.033788986713966906,
#   0.006331300462045775,
#   0.022451321403069713,
#   -0.05333378666189326,
#   0.11250722935596258,
#   -0.0986862990942754,
#   -0.038407276822558956,
#   0.06534607114622126,
#   -0.03658927304388193,
#   0.08173154198248156,
#   -0.010855899871968333,
#   -0.12125194031217035,
#   -0.06497915976269297,
#   0.07087795805505515,
#   -0.034223049894356095,
#   -0.09421876583427924,
#   -0.04082770176624528,
#   0.08571468581176056,
#   0.03448199447282363,
#   0.008396784914911137,
#   0.08560376170760975,
#   0.037096944287490885,
#   -0.04014273013920899,
#   0.0163362872963404,
#   -0.014861161385988808,
#   0.01889702295451201,
#   0.01441221470090781,
#   0.10909680124090926,
#   0.02131340634890755,
#   -0.008284460400604488,
#   0.04495933580661848,
#   -0.06156838025441047,
#   -0.008895517617755644,
#   0.12899528624115142,
#   0.1389135167962614,
#   -0.030384079396894137,
#   -0.009247425274793386,
#   0.017817185460124563,
#   -0.03872454642313983,
#   -0.09499016778860359,
#   0.0504850449712535,
#   0.050768504336714315,
#   -0.03411895195382186,
#   -0.0689912944915072,
#   0.026936351604295083,
#   -0.04221117235347904,
#   0.0035383792819914106,
#   -0.00022487122345360433,
#   0.10461286923431956,
#   0.00248956726628613,
#   0.07964270925070949,
#   0.03955440707423108,
#   0.0954016783488374,
#   0.02466982250012073,
#   -0.06519761799999024,
#   0.08629475613078164,
#   -0.11532230962632539,
#   0.03046837866481944,
#   0.02048259964877097,
#   -0.07351365581960145,
#   0.028624307384948366,
#   -0.07231494222198975,
#   -0.10914579964817506,
#   0.03671046828224611,
#   -0.0074742899273800845,
#   0.06327667602610099,
#   0.057117004191191256,
#   0.024673971314925325,
#   0.0035148033512317767,
#   -0.11978548847141646,
#   -0.13798029340801854,
#   -0.07868788546587346,
#   -0.03033094167953898,
#   -0.05245673211734392,
#   -0.06687887656437574,
#   0.014682244013833667,
#   -0.13114403068078673,
#   -0.08144593586695592,
#   0.052255785397392174,
#   -0.03166925258246245,
#   0.04521505205730847,
#   0.020319232925587016,
#   0.031456635394944144,
#   0.01951417446702841,
#   -0.035064008322228446,
#   0.005043374624303709,
#   -0.05525073836126815,
#   0.19460359813826678,
#   -0.11530630883214421,
#   0.10305352412632374,
#   0.07173911699839586,
#   0.15576324759673277,
#   -0.027904177156063525,
#   -0.038870683698513986,
#   -0.031375949591298635,
#   0.03317041404376475,
#   -0.02766703261345249,
#   -0.11623147528648303,
#   0.03051556040936454,
#   0.019681813145588478,
#   -0.1896035199280437,
#   0.04001501645139349,
#   -0.03582945317002206,
#   0.021781198271737523,
#   0.02585186270891171,
#   -0.06958825759957676,
#   -0.0502651323902743,
#   0.03700071480889555,
#   -0.12197303166877305,
#   -0.14755968151399124,
#   0.02889873768246254,
#   0.023968929295197228,
#   0.04155593051702233,
#   0.09886330539167609,
#   0.07012671599439635,
#   -0.08045228022145601,
#   0.021709793463006832,
#   0.020006755475010962,
#   -0.024950095774105563,
#   -0.028741016901941308,
#   -0.025158063044198542,
#   0.014048264146179434,
#   0.011853958959894939,
#   -0.06479425768679192,
#   -0.02095852056369374,
#   -0.013090009333186714,
#   0.08965588504168842,
#   -0.0027359967307774014,
#   0.004954913214742618,
#   -0.020933633930862783,
#   0.1338763503561342,
#   -0.07300297844392745,
#   -0.036510825806690406,
#   0.020962840953174577,
#   -0.008322701946017474,
#   -0.07840301975555164,
#   0.09292324800775198,
#   -0.09452992073495814,
#   0.04920674939951475,
#   0.04383209651330411,
#   0.04655670347451313,
#   -0.02989008413075034,
#   -0.052315823252365945,
#   -0.032504458622769405,
#   0.013449390188782218,
#   0.03979808679614649,
#   0.0925181225860836,
#   0.06303168127061198,
#   -0.025151243725085592,
#   -0.05246875148914221,
#   -0.10877933943786999,
#   0.04527719639981065,
#   0.07006389520955736,
#   0.012802842625456279,
#   -0.06875826555163478,
#   0.13971917321488014,
#   -0.07936595491898046,
#   -0.028539081649361364,
#   -0.05154529296731347,
#   -0.033398433207830536,
#   -0.04241135156387621,
#   -0.0139047565676087,
#   0.006243933892577047,
#   -0.10329946096105935,
#   -0.05631014819047664,
#   -0.024683340085843497,
#   -0.03711117827897503,
#   0.04314426969155605,
#   0.01466622258342909,
#   0.04746681599752556,
#   0.01655002026205743,
#   -0.035263361156010475,
#   0.020639441718971696,
#   -0.043779067924624826,
#   0.056334823279977186,
#   -0.029982476055277374,
#   -0.010669703580967749,
#   -0.15429800134458915,
#   -0.08205865785202704,
#   0.022956767509757725,
#   0.05384060912746769,
#   0.011950615590533786,
#   0.0009068194080370517,
#   -0.07597965275492946,
#   0.032839071822039045,
#   0.06428967008369213,
#   -0.04501767133294621,
#   -0.013084215381789832,
#   0.001167995107518749,
#   -0.028530209085973368,
#   -0.025772080655846352,
#   0.039892328615742656,
#   -0.09408316502765324,
#   0.0627495735475101,
#   -0.05111082861055216,
#   0.060116806814892954,
#   0.03310304586333146,
#   -0.015555684642054146,
#   -0.02535914823351426,
#   -0.014792350867372406,
#   0.014073275698644139,
#   0.030494029924733823,
#   -0.09923111082934533,
#   -0.08181539171053132,
#   -0.08482585220240502,
#   0.023126654288448734,
#   -0.01588673574493704,
#   -0.11223015215403187,
#   0.025439573404709037,
#   0.036125133893813555,
#   0.04740167659888783,
#   0.009910242382792589,
#   -0.0572799409758975,
#   -0.005534072522072719,
#   0.1209220472760748,
#   0.003477239454602099,
#   0.03491320818134547,
#   -0.016334340178680407,
#   -0.07364286720821411,
#   0.010063133900960253,
#   -0.02472298791291827,
#   -0.03777649545235384,
#   -0.0068468965233563495,
#   -0.09794408562935786,
#   0.09957538378428588,
#   0.14917883939748044,
#   -0.09693275125187562,
#   -0.01409724737146334,
#   -0.11645921776901424,
#   -0.11208847220786389,
#   -0.10858129420571316,
#   -0.06753912183956601,
#   0.012435624699532966,
#   -0.02619741241119833,
#   -0.06992105958051198,
#   0.04022158505995854,
#   -0.019488638148247972,
#   -0.053782897587918654,
#   -0.029337056623436553,
#   -0.011274619358561111,
#   0.06124344300157247,
#   0.003195013456169349,
#   -0.006235795497298469,
#   -0.006721779306605669,
#   -0.005847983524743583,
#   0.03093631304317057,
#   -0.11273165446609745,
#   0.07672070129097186,
#   0.08132026208940601,
#   0.047970288307489284,
#   -0.07232274009652961,
#   -0.048344789268858435,
#   -0.05888083288456514,
#   -0.0378533017618885,
#   -0.02321329330929167,
#   0.06267957851745187,
#   -0.01483608372628531,
#   0.06249804587777952,
#   -0.02750808280693917,
#   0.00640288225080532,
#   -0.11122600037246322,
#   -0.09264380505276293,
#   0.043149342364632304,
#   -0.009886485975750148,
#   0.021580185183800893,
#   -0.06388327734231147,
#   0.022245651265407673,
#   -0.016969224606107502,
#   -0.04703029273943926,
#   0.02341074432954926,
#   0.019683281370090455,
#   0.08207921683546893,
#   -0.04240526612437634,
#   -0.008617602693783866,
#   -0.0957138164450324,
#   -0.05990191562309022,
#   -0.10159409855651802,
#   -0.05785075327953315,
#   0.06100237073985504,
#   -0.0009367557660961978,
#   -0.011419673724073931,
#   -0.13457933146141876,
#   -0.012800318423852985,
#   -0.16507130172265505,
#   -0.05585171059963834,
#   -0.12268709818565249,
#   -0.08549240678619796,
#   0.08239064795178308,
#   0.03845750151934446,
#   -0.01864269282497233,
#   -0.025610088993241575,
#   -0.05473402012482609,
#   0.004010424232433252,
#   0.016357667552934885,
#   -0.028288566384251368,
#   -0.027768485956936928,
#   -0.007920638984433737,
#   -0.06794544919644352,
#   0.03680402166325436,
#   -0.09673729249450957,
#   -0.04321977360008589,
#   -0.08142685480551037,
#   -0.1616260593548393,
#   0.06640019659521279,
#   0.06575869838993142,
#   -0.07292971448065799,
#   -0.025295259106560053,
#   -0.03194243283086884,
#   -0.063539287014029,
#   0.11602624085616675,
#   -0.08781363825769972,
#   0.08946985781905248,
#   -0.06748961149893873,
#   0.0771277049245942,
#   0.039718555345643836,
#   0.037299504114047366,
#   -0.05440415366751239,
#   0.04677736883042449,
#   -0.032988073059286194,
#   0.0273466981121242,
#   -0.09062889057678625,
#   -0.12025656581081101,
#   -0.025002564927030235,
#   0.04249508021844939,
#   0.014978518701051158,
#   0.03596490493659843,
#   0.04078902483180613,
#   -0.015777719820986746,
#   0.030101130399353693,
#   1.4525685372746011e-05,
#   0.11442658561856156,
#   -0.14696568731226378,
#   -0.02712444088247068,
#   0.023342964361855678,
#   0.05087373793478456,
#   0.010223481554911373,
#   -0.15277638899954482,
#   0.013119109538349605,
#   -0.04493508534490864,
#   0.009780420236376486,
#   0.025118924962363565,
#   -0.04372664555405947,
#   -0.009837821609034236,
#   0.024798589110849534,
#   -0.002198252131462297,
#   -0.03211886012679521,
#   -0.06671130878631715,
#   0.005916428481464564,
#   -0.0037856199295145387,
#   0.08203488009107929,
#   0.009565590305799176,
#   -0.07171994968524054,
#   0.03572598665626536,
#   -0.06417622528854139,
#   0.13080215286155905,
#   -0.020536251154419816,
#   -0.007540129355120939,
#   -0.054152083808991947,
#   0.08030354531636164,
#   0.029255881448408516,
#   0.0037352769790484075,
#   0.049846711686271306,
#   -0.081373500895209,
#   0.03104821357420029,
#   -0.0015383157968429373,
#   -0.10085351621929561,
#   -0.02152911331884333,
#   -0.0739063103454729,
#   -0.09703800548480856,
#   0.013123834358935937,
#   0.04321145806117066,
#   -0.05879344868337988,
#   0.08091517617429567,
#   -0.012752064591396106,
#   -0.011780558081847303,
#   0.07901769921837243,
#   0.041257344480225555,
#   -0.1250671021309433,
#   0.01290615587314825,
#   0.010758120481646927,
#   -0.12537212040366086,
#   -0.06408422992719487,
#   0.03500639822640572,
#   -0.0964734679272361,
#   -0.030485312690112565,
#   0.13429191974314136,
#   -0.04536764023420936,
#   -0.11835874522571643,
#   -0.07411143574932666,
#   -0.06844662220465914,
#   0.013629224819515784,
#   -0.051785819931561505,
#   0.027249623871311357,
#   -0.03171643228983001,
#   -0.0951108637782827,
#   -0.012376944533198042,
#   0.03364105027091746,
#   -0.025553494373909302,
#   -0.053588622418402565,
#   -0.014188317101751835,
#   0.02468586880998558,
#   -0.02553596678987269,
#   -0.03048811203421309,
#   -0.08097531648515854,
#   0.020885173495774012,
#   -0.0655153215304658,
#   0.17076359975986044,
#   0.02942922109104984,
#   -0.012801367242273543,
#   0.06771289554391124,
#   0.09439591027351035,
#   -0.04866898624472782,
#   0.12754485405528726,
#   0.13205443511760606,
#   0.03789246800538315,
#   -0.09739251754958822,
#   -0.05045049887010222,
#   0.055446736494818794,
#   0.12730246686165003,
#   0.1521354615900954,
#   0.10314213340408607,
#   -0.03697864868110301,
#   -0.06651496411617686,
#   0.09250656575713023,
#   0.03445622667570447,
#   0.07130329674787994,
#   0.011647645480692859,
#   0.04352281162622518,
#   -0.04987121084589674,
#   -0.1391821630624257,
#   -0.1501591383142884,
#   -0.014352992254250907,
#   0.06966624902246998,
#   0.03127637890778878,
#   0.07727350959720347,
#   0.1836385010519166,
#   -0.028125132098947958,
#   -0.10389127090314787,
#   0.003179246283952608,
#   -0.10497469637537726,
#   -0.05099217131497369,
#   -0.04755604022447635,
#   0.22516528305517802,
#   0.09540040368257152,
#   -0.1368760646367715,
#   -0.09530355342233321,
#   -0.04853429410376897,
#   -0.06648876754890942,
#   -0.032979822872418296,
#   0.07674871064083177,
#   -0.03545914590673682,
#   -0.035705620071839306,
#   -0.03396258225827786,
#   -0.02212059135645994,
#   -0.04434799015951185,
#   0.006715044459177477,
#   0.110233107371279,
#   0.05154506794511171,
#   0.11054897828553933,
#   0.15297265908904834,
#   0.0661321845612175,
#   0.0628305049196971,
#   -0.01931621859942645,
#   0.03892809835553557,
#   -0.008784187864019799,
#   0.07544438380382523,
#   -0.033670980713209175,
#   -0.04434542798752794,
#   -0.06261239806275753,
#   -0.11217993343951704,
#   0.04984417445770184,
#   0.05518590629369413,
#   0.10356544465778761,
#   -0.00438449077497971,
#   -0.011988537514904252,
#   0.019891030191402592,
#   0.05403145668813991,
#   -0.068183786355414,
#   0.0375962344049654,
#   -0.005345756748420527,
#   -0.003723584175254757,
#   -0.03312112271149026,
#   0.03303184393193348,
#   0.021143757900047078,
#   -0.05084806142235543,
#   -0.08423848936669032,
#   -0.09336451917871535,
#   -0.027697780571608988,
#   0.04531313216075006,
#   -0.044917386793947855,
#   -0.05707044516542403,
#   -0.006565326102025537,
#   -0.10862072006078805,
#   0.007689694788917123,
#   0.01879572771070137,
#   0.021134056440557103,
#   -0.09230499883985921,
#   0.02287633556889901,
#   -0.015767660298202202,
#   0.031220491425127506,
#   -0.010373888203558224,
#   0.011879856018978785,
#   -0.05463582292416014,
#   -0.016277902939108913,
#   -0.06964921045698347,
#   -0.008773499376925287,
#   0.07063873800112574,
#   0.09714577806165536,
#   -0.07967629903483164,
#   0.06406657423304374,
#   0.07710088827811212,
#   -0.00364273683765326,
#   0.07783179131365436,
#   0.04564386208040716,
#   -0.10882974877659812,
#   0.13817543299000867,
#   0.09686846080042599,
#   -0.05829424639168579,
#   -0.10044529984108408,
#   -0.09166206946093958,
#   -0.08204704109314243,
#   -0.06769964618085211,
#   0.10885451408014113,
#   0.022198713527116,
#   -0.04058952822437156,
#   -0.07588102044469736,
#   0.011692906780211842,
#   0.10395935391571243,
#   -0.048536098577374176,
#   0.08798250464666424,
#   -0.009354060955846677,
#   -0.03682697349187869,
#   -0.051059523283994324,
#   0.10022376202680228,
#   -0.07001918795089068,
#   0.12980182515987693,
#   -0.0962208641329152,
#   -0.0033934640884822898,
#   0.02167967578715313,
#   -0.10285870028384636,
#   0.08025615299191102,
#   0.029474064821513934,
#   0.0446059393069973,
#   -0.04607967438992944,
#   0.028696486183543257,
#   -0.03810045833804132,
#   -0.024694263603587174,
#   0.0661699829680753,
#   0.1023396279843567,
#   -0.002125794754045174,
#   -0.11468124060782081,
#   0.1550010970817084,
#   0.04933448613566149,
#   0.07216823454475474,
#   0.005665953047721217,
#   0.015683841844950308,
#   -0.07398865738893434,
#   -0.07408771847722484,
#   -0.022243590975794092,
#   0.0051438193900388285,
#   -0.09994716169255291,
#   0.04508861877894432,
#   -0.030014458622014573,
#   0.008839689605212087,
#   -0.00990397763928641,
#   0.028098137336410645,
#   -0.018885703496437145,
#   0.06407908909472582,
#   0.05930416962913654,
#   0.004680604419768031,
#   -0.07122075710440967,
#   -0.01122159238687992,
#   -0.008934014712517424,
#   0.00401826266100791,
#   0.010377682777907182,
#   0.06922908527545601,
#   -0.051211952531101446,
#   0.0808422313814745,
#   -0.028519973712919366,
#   -0.05859053572088513,
#   0.003073880299755416,
#   -0.039115161640470575,
#   -0.043058271220377975,
#   -0.04418653037515696,
#   -0.06642172709380212,
#   0.0017082552397820194,
#   0.06434370480364748,
#   -0.05857187338542502,
#   -0.05043947486043443,
#   0.10725887914658472,
#   -0.003642152617922889,
#   0.03419944153111487,
#   -0.0885154890693709,
#   -0.10183432614739196,
#   0.06192870848293808,
#   -0.0342011172471377,
#   -0.01446567815948363,
#   -0.05353728701703275,
#   0.04041987626298216,
#   0.004441478477836824,
#   0.05522965245442535,
#   0.05512343774306494,
#   -0.05985305658954587,
#   0.021509004375934282,
#   -0.07224090198709554,
#   -0.138843307812774,
#   0.017920296095773836,
#   0.03394324061192755,
#   0.10959651133799042,
#   -0.011806447043181123,
#   0.02152432543899785,
#   -0.08630003099741579,
#   -0.029465122255453835,
#   -0.08783810697085315,
#   0.03443106006464092,
#   -0.03297898657057985,
#   -0.16261469841616893,
#   -0.020422386206861987,
#   -0.12935474640228328,
#   -0.01022109985263775,
#   0.013959901316365375,
#   -0.044211645335346716,
#   0.05510326417969402,
#   -0.08087026027301292,
#   -0.04185683841639509,
#   0.022981193673441425,
#   -0.03912932065887631,
#   0.03543225886431145,
#   -0.12991827279445367,
#   -0.04639571752641558,
#   -0.0417320236662615,
#   0.061997282181218694,
#   0.07810738887481428,
#   -0.006010457664423541,
#   0.026390150025957126,
#   0.05321818803773404,
#   -0.09702555793655065,
#   -0.024609390429828792,
#   0.019688762503504265,
#   -0.037651372403376016,
#   -0.05477139655355323,
#   -0.050985760819147075,
#   -0.01967220992937513,
#   0.006898940384610697,
#   0.044801514038663726,
#   0.027565962368369057,
#   0.03560341316786797,
#   0.030632848815367097,
#   0.05813457662782184,
#   0.06812118595948569,
#   -0.058490928847653834,
#   -0.011303898045651906,
#   0.01305438201466913,
#   0.11067622056636317,
#   -0.05229672749184466,
#   -0.028157279537401436,
#   0.08365397680792697,
#   0.02733281644507457,
#   -0.042314699082121265,
#   0.043841818900698826,
#   -0.03698352642607716,
#   -0.05680787866906378,
#   0.1459045972836126,
#   0.002635306031429252,
#   0.00305397207690028,
#   0.0699526092300129,
#   0.0029878747739946476,
#   -0.08699251768657668,
#   -0.027335851119232757,
#   0.052613277792621815,
#   0.03592210178592303,
#   0.026882118097407925,
#   0.0009719819850122491,
#   0.0693258073811549,
#   -0.018715895003579064,
#   -0.0761352723944313,
#   0.12086594838985398,
#   -0.01656568252230528,
#   0.04770156353786881,
#   0.05788131259925855,
#   -0.05671985985138228,
#   -0.010823220010831136,
#   -0.06054363470673785,
#   -0.05382990550478972,
#   -0.09516683942138293,
#   -0.057403835714488594,
#   0.006414833772639739,
#   -0.13403526742117045,
#   -0.043045610576294635,
#   0.014169492496190372,
#   -0.15046903571108317,
#   0.02631092521173528,
#   -0.038627050995021506,
#   0.018055655875128807,
#   -0.10188669381203574,
#   -0.027184789508424956,
#   -0.03833756179376557,
#   -0.04347774486270772,
#   0.05977724102638149,
#   -0.03739911136462659,
#   0.011516750167134049,
#   0.00011090095248356135,
#   -0.00515662454316157,
#   -0.034283992688564524,
#   -0.0010522426360619619,
#   0.08158227597881407,
#   0.01347491166088588,
#   -0.08425192374276058,
#   -0.0964204727331257,
#   -0.17857624715972698,
#   0.059544554767484215,
#   -0.10439278857801071,
#   0.061835352869472615,
#   0.026047744074253032,
#   0.15964252162377157,
#   -0.07438552522528852,
#   -0.1358630948834918,
#   -0.004845252047379844,
#   -0.0684012920218251,
#   -0.07030789974190732,
#   0.017406452002889594,
#   -0.07594779465465429,
#   -0.0923256160815118,
#   -0.042685015309777086],
#  'quants':               0
#  0.025 -0.131182
#  0.975  0.132073,
#  'p_value': 0.9394780052685153}

# %% [markdown]
# • усредненная разность между средними в контрольной и тестовой группах равняется 20;
# • усредненная разность между средними в контрольной и тестовой без выбросов группах равняется 0.

# %% [markdown]
# Манн-Уитни и Бутстрап проверяют разные гипотезы. С помощью бутстрапа мы проверяем нулевую гипотезу о равенстве средних, а Манн-Уитни о равенстве распределений. Что значит равенство распределений? Это значит, что случайно выбранное значение из одной выборки может быть равновероятно больше или меньше случайного значения из другой выборки.

# %% [markdown]
# Про разное количество наблюдений в выборках: Манн-Уитни как и любой статистический оценщик не очень приветлив к дисбалансу. Это сказывается в первую очередь на мощности критерия – чем сильнее дисбаланс, тем реже критерий будет обнаруживать реальную разницу (эффект).

# %% [markdown]
# ## Итого
# Тестовая выборка имеет большие выбросы, что сильно искажает нам среднее значение. Применяя бутстрап с оценкой среднего, мы могли бы отклонить нулевую гипотезу о равенстве средних и сделать вывод, что тестовая и контрольная выборка имеют различия
# Однако, убрав выбросы, мы уже не можем отклонить нулевую гипотезу, так как p-value сильно больше 0.05. U-критерий Манна-Уитни так же не дал отклонить нулевую гипотезу.
