# %% [markdown]
# ## Дополнительный проект

# %% [markdown]
# В рамках дополнительного проекта попробуем освоить API, позволяющий получать данные о музейных коллекциях. Это задание может пригодиться для большего понимания того, какими способами можно собирать и обрабатывать данные, например, для собственного проекта или другой рабочей задачи. Также вы можете более глубоко изучить документацию, чтобы потом исследовать другие интересные для себя вопросы по полученным данным :)

# %% [markdown]
# ## Описание API

# %% [markdown]
# __Документация__: https://metmuseum.github.io
#
# Ключ: для использования выбранного API (на момент написания задания) ключ не требуется :)
#
# Всего есть 4 основных раздела:
#
# - Объекты (Objects)
# - Объект (Object) – данные об объекте (например, о картине)
# - Департаменты (Departments) –  данные о департаменте/разделе (например, "Современное искусство")
# - Поиск (Search) – используется для поиска
#
# В рамках задач поработаем с блоками Object и Search.

# %% [markdown]
# ### 1

# %% [markdown]
# Для начала, импортируйте нужные библиотеки:

# %%
import requests
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Сам запрос к API должен состоять из нескольких параметров. Пример обращения к поиску (Search):

# %%
r = requests.get('https://collectionapi.metmuseum.org/public/collection/v1/search?q=QUERY')
res = r.json()

# %%
res
# Out:
# {'total': 15,
#  'objectIDs': [848290,
#   778803,
#   839361,
#   208967,
#   436180,
#   435821,
#   437449,
#   60451,
#   839021,
#   857478,
#   437489,
#   503341,
#   436105,
#   436883,
#   436283]}

# %% [markdown]
# где __QUERY__ – ключевое слово.

# %% [markdown]
# Предположим, ваша задача – найти все произведения, связанные с подсолнухами. Выполните поиск по слову "sunflowers". Внимательно посмотрите на формат ответа и сохраните id полученных объектов в список sunflower_ids.
#
# В качестве ответа выберите id объектов (3), которые присутствуют в полученном списке:

# %% [markdown]
# - __2032__
# - __437329__
# - __436524__
# - 16822570
# - 20149

# %%
r = requests.get('https://collectionapi.metmuseum.org/public/collection/v1/search?q=sunflowers')
sunflowers = r.json()

# %%
sunflowers
# Out:
# {'total': 89,
#  'objectIDs': [436524,
#   484935,
#   437112,
#   210191,
#   431264,
#   397949,
#   656530,
#   480725,
#   486590,
#   485308,
#   375281,
#   705155,
#   11922,
#   2032,
#   343052,
#   20141,
#   2019,
#   347980,
#   208554,
#   403496,
#   360837,
#   437115,
#   207869,
#   400581,
#   423400,
#   707887,
#   223828,
#   682927,
#   57922,
#   649813,
#   79739,
#   193938,
#   339347,
#   208218,
#   202228,
#   437984,
#   436534,
#   761604,
#   437329,
#   436252,
#   363282,
#   207753,
#   822570,
#   816522,
#   487043,
#   436580,
#   437526,
#   203893,
#   367434,
#   190739,
#   423237,
#   262423,
#   839296,
#   367817,
#   822590,
#   822589,
#   13644,
#   18362,
#   820022,
#   648617,
#   761731,
#   814626,
#   892559,
#   207967,
#   626832,
#   262430,
#   262428,
#   841928,
#   707697,
#   205386,
#   262378,
#   426804,
#   633526,
#   369073,
#   747779,
#   852414,
#   427872,
#   895564,
#   436530,
#   436535,
#   436121,
#   436529,
#   724844,
#   436144,
#   437980,
#   631808,
#   834580,
#   834585,
#   834765]}

# %%
sunflower_ids = sunflowers['objectIDs']

# %%
sunflower_ids
# Out:
# [436524,
#  484935,
#  437112,
#  210191,
#  431264,
#  397949,
#  656530,
#  480725,
#  486590,
#  485308,
#  375281,
#  705155,
#  11922,
#  2032,
#  343052,
#  20141,
#  2019,
#  347980,
#  208554,
#  403496,
#  360837,
#  437115,
#  207869,
#  400581,
#  423400,
#  707887,
#  223828,
#  682927,
#  57922,
#  649813,
#  79739,
#  193938,
#  339347,
#  208218,
#  202228,
#  437984,
#  436534,
#  761604,
#  437329,
#  436252,
#  363282,
#  207753,
#  822570,
#  816522,
#  487043,
#  436580,
#  437526,
#  203893,
#  367434,
#  190739,
#  423237,
#  262423,
#  839296,
#  367817,
#  822590,
#  822589,
#  13644,
#  18362,
#  820022,
#  648617,
#  761731,
#  814626,
#  892559,
#  207967,
#  626832,
#  262430,
#  262428,
#  841928,
#  707697,
#  205386,
#  262378,
#  426804,
#  633526,
#  369073,
#  747779,
#  852414,
#  427872,
#  895564,
#  436530,
#  436535,
#  436121,
#  436529,
#  724844,
#  436144,
#  437980,
#  631808,
#  834580,
#  834585,
#  834765]

# %%
search_ids = [2032, 437329, 436524, 16822570, 20149]

# %%
correct_ids = [i for i in search_ids if i in sunflower_ids]

# %%
correct_ids
# Out:
# [2032, 437329, 436524]

# %% [markdown]
# ### 2

# %% [markdown]
# Отлично! На предыдущем шаге мы получили результаты поиска. Следущий этап – собрать информацию об этих объектах.

# %% [markdown]
# Пример текста запроса для получения информации об одном объекте (Object):

# %% [markdown]
# Пример текста запроса для получения информации об одном объекте (Object):

# %%
r_test = requests.get(f'https://collectionapi.metmuseum.org/public/collection/v1/objects/OBJECT_ID')
obj_test = r_test.json()

# %%
obj_test
# Out:
# {'message': 'could not parse objectID'}

# %% [markdown]
# где __OBJECT_ID__ – id объекта.

# %% [markdown]
# Выполните запрос для объекта 437980. Для проверки соотнесите полученные параметры с их значениями:

# %% [markdown]
# department > European Paintings
# objectID > 437980
# artistDisplayName > Vincent van Gogh
# culture > ''
# objectName > Painting
# GalleryNumber > 825
# title > Cypresses

# %%
r_test = requests.get(f'https://collectionapi.metmuseum.org/public/collection/v1/objects/437980')
obj_test = r_test.json()

# %%
obj_test
# Out:
# {'objectID': 437980,
#  'isHighlight': False,
#  'accessionNumber': '49.30',
#  'accessionYear': '1949',
#  'isPublicDomain': True,
#  'primaryImage': 'https://images.metmuseum.org/CRDImages/ep/original/DP130999.jpg',
#  'primaryImageSmall': 'https://images.metmuseum.org/CRDImages/ep/web-large/DP130999.jpg',
#  'additionalImages': [],
#  'constituents': [{'constituentID': 161947,
#    'role': 'Artist',
#    'name': 'Vincent van Gogh',
#    'constituentULAN_URL': 'http://vocab.getty.edu/page/ulan/500115588',
#    'constituentWikidata_URL': 'https://www.wikidata.org/wiki/Q5582',
#    'gender': ''}],
#  'department': 'European Paintings',
#  'objectName': 'Painting',
#  'title': 'Cypresses',
#  'culture': '',
#  'period': '',
#  'dynasty': '',
#  'reign': '',
#  'portfolio': '',
#  'artistRole': 'Artist',
#  'artistPrefix': '',
#  'artistDisplayName': 'Vincent van Gogh',
#  'artistDisplayBio': 'Dutch, Zundert 1853–1890 Auvers-sur-Oise',
#  'artistSuffix': '',
#  'artistAlphaSort': 'Gogh, Vincent van',
#  'artistNationality': 'Dutch',
#  'artistBeginDate': '1853',
#  'artistEndDate': '1890',
#  'artistGender': '',
#  'artistWikidata_URL': 'https://www.wikidata.org/wiki/Q5582',
#  'artistULAN_URL': 'http://vocab.getty.edu/page/ulan/500115588',
#  'objectDate': '1889',
#  'objectBeginDate': 1889,
#  'objectEndDate': 1889,
#  'medium': 'Oil on canvas',
#  'dimensions': '36 3/4 x 29 1/8 in. (93.4 x 74 cm)',
#  'measurements': [{'elementName': 'Overall',
#    'elementDescription': None,
#    'elementMeasurements': {'Height': 93.4, 'Width': 74}},
#   {'elementName': 'Frame',
#    'elementDescription': None,
#    'elementMeasurements': {'Depth': 10.795,
#     'Height': 116.2052,
#     'Width': 96.5202}},
#   {'elementName': 'Other',
#    'elementDescription': 'glass',
#    'elementMeasurements': {'Height': 94.29769, 'Width': 76.517654}}],
#  'creditLine': 'Rogers Fund, 1949',
#  'geographyType': '',
#  'city': '',
#  'state': '',
#  'county': '',
#  'country': '',
#  'region': '',
#  'subregion': '',
#  'locale': '',
#  'locus': '',
#  'excavation': '',
#  'river': '',
#  'classification': 'Paintings',
#  'rightsAndReproduction': '',
#  'linkResource': '',
#  'metadataDate': '2023-01-26T04:46:50.13Z',
#  'repository': 'Metropolitan Museum of Art, New York, NY',
#  'objectURL': 'https://www.metmuseum.org/art/collection/search/437980',
#  'tags': [{'term': 'Landscapes',
#    'AAT_URL': 'http://vocab.getty.edu/page/aat/300132294',
#    'Wikidata_URL': 'https://www.wikidata.org/wiki/Q191163'},
#   {'term': 'Cypresses',
#    'AAT_URL': 'http://vocab.getty.edu/page/aat/300343641',
#    'Wikidata_URL': 'https://www.wikidata.org/wiki/Q146911'}],
#  'objectWikidata_URL': 'https://www.wikidata.org/wiki/Q867510',
#  'isTimelineWork': True,
#  'GalleryNumber': '825'}

# %%
obj_test['department']
# Out:
# 'European Paintings'

# %%
obj_test['objectID']
# Out:
# 437980

# %%
obj_test['artistDisplayName']
# Out:
# 'Vincent van Gogh'

# %%
obj_test['culture']
# Out:
# ''

# %%
obj_test['objectName']
# Out:
# 'Painting'

# %%
obj_test['GalleryNumber']
# Out:
# '825'

# %%
obj_test['title']
# Out:
# 'Cypresses'

# %% [markdown]
# ### 3

# %% [markdown]
# Теперь напишите цикл, с помощью которого будет собрана информация об объектах, которые были получены на 2 шаге. Результаты запишите в датафрейм, а именно – следующие параметры:

# %% [markdown]
# - objectID – id объекта
# - title – название
# - artistDisplayName – автор
# - department – департамент
# - objectBeginDate – дата (начало)
# - objectEndDate – дата (конец)
# - period – название периода
# - objectName – название/категория объекта
# - culture – культура
#
# Сколько объектов относятся к японской культуре? (culture –Japan)

# %% [markdown]
# - __1__
# - 10
# - 5
# - 22
# - 45
# - 18

# %%
res["objectIDs"]
# Out:
# [848290,
#  778803,
#  839361,
#  208967,
#  436180,
#  435821,
#  437449,
#  60451,
#  839021,
#  857478,
#  437489,
#  503341,
#  436105,
#  436883,
#  436283]

# %%
ids = list(res["objectIDs"])

# %%
finalData = pd.DataFrame()

# %%
r_test = requests.get(f'https://collectionapi.metmuseum.org/public/collection/v1/objects/437980')
obj_test = r_test.json()

# %%
for i in ids:
    try:
        r_test = requests.get(f'https://collectionapi.metmuseum.org/public/collection/v1/objects/{i}')
        obj_test = r_test.json()
        dframe = pd.DataFrame({'objectID': obj_test['objectID'], 'title': obj_test['title'],
                               'artistDisplayName': obj_test['artistDisplayName'], 'department': obj_test['department'],
                               'objectBeginDate': obj_test['objectBeginDate'], 'objectEndDate': obj_test['objectEndDate'],
                               'period': obj_test['period'], 'objectName': obj_test['objectName'], 'culture': obj_test['culture']}, index=[0])
        finalData = finalData.append(dframe)
    except:
        continue

# %%
finalData.reset_index(drop=True)
# Out:
#     objectID                                              title  \
# 0     848290                                   What are we? III
# 1     778803                                           Ensemble
# 2     839361                                        Earth & Sky
# 3     208967                                        Tobacco box
# 4     436180                                        The Natchez
# 5     435821  Portrait of a Woman, Said to Be Emma (1765–181...
# 6     437449  The Honorable Henry Fane (1739–1802) with Inig...
# 7      60451                           Letter to the Nun Jōjūbō
# 8     839021                   Synthèse photo-cinématographique
# 9     857478               Kodak Advertising Department All-bum
# 10    437489                     Christ Appearing to His Mother
# 11    503341                                       Square Piano
# 12    436105                              The Death of Socrates
# 13    436883                                   Among the Humble
# 14    436283                        Virgin and Child in a Niche
#
#           artistDisplayName                              department  \
# 0               Sosa Joseph             Modern and Contemporary Art
# 1                   Vaquera                       Costume Institute
# 2             Lorna Simpson             Modern and Contemporary Art
# 3                            European Sculpture and Decorative Arts
# 4          Eugène Delacroix                      European Paintings
# 5                 Adam Buck                      European Paintings
# 6       Sir Joshua Reynolds                      European Paintings
# 7           Myōe Kōben 明恵高弁                               Asian Art
# 8             Jean Dréville                             Photographs
# 9                   Unknown                             Photographs
# 10          Juan de Flandes                      European Paintings
# 11                                              Musical Instruments
# 12      Jacques Louis David                      European Paintings
# 13  Léon-Augustin Lhermitte                      European Paintings
# 14    Netherlandish Painter                      European Paintings
#
#     objectBeginDate  objectEndDate                       period  \
# 0              2012           2012
# 1              2017           2018
# 2              2018           2018
# 3              1729           1739
# 4              1823           1835
# 5              1804           1804
# 6              1761           1766
# 7              1221           1221  Kamakura period (1185–1333)
# 8              1927           1927
# 9              1940           1940
# 10             1491           1501
# 11             1767           1800
# 12             1787           1787
# 13             1905           1905
# 14             1495           1505
#
#                       objectName   culture
# 0                       Painting
# 1                       Ensemble  American
# 2                        Collage
# 3                    Tobacco box
# 4                       Painting
# 5            Painting, miniature
# 6                       Painting
# 7                 Hanging scroll     Japan
# 8                     Photograph
# 9              Photograph; Album
# 10  Painting, part of a triptych
# 11                  Square Piano  American
# 12                      Painting
# 13                      Painting
# 14                      Painting

# %%
finalData.query('culture == "Japan"').shape
# Out:
# (1, 9)

# %% [markdown]
# ### 4

# %% [markdown]
# Теперь попробуем построить более сложный запрос с помощью секции "Search"! На этот раз параметры необходимо передать через "&", например, departmentId (id департамента – 1) и q (ключевое слово – cat):

# %%
r = requests.get('https://collectionapi.metmuseum.org/public/collection/v1/search?departmentId=6&q=cat')
cats = r.json()

# %%
cats
# Out:
# {'total': 3056,
#  'objectIDs': [49698,
#   49470,
#   53222,
#   36221,
#   60873,
#   70541,
#   752008,
#   43402,
#   47358,
#   49467,
#   54747,
#   54626,
#   55919,
#   59775,
#   55923,
#   36075,
#   50826,
#   57204,
#   53653,
#   42922,
#   56602,
#   47051,
#   47052,
#   72842,
#   69780,
#   59121,
#   38952,
#   39199,
#   38177,
#   59903,
#   73809,
#   59763,
#   49050,
#   58462,
#   38158,
#   38160,
#   39092,
#   50780,
#   38162,
#   38994,
#   45282,
#   53441,
#   55948,
#   54124,
#   59248,
#   36411,
#   58779,
#   52996,
#   73046,
#   671015,
#   42932,
#   45065,
#   56780,
#   42915,
#   59249,
#   36346,
#   38949,
#   51660,
#   38452,
#   39698,
#   39699,
#   670898,
#   75200,
#   39764,
#   69410,
#   68841,
#   55148,
#   76442,
#   37011,
#   36621,
#   58218,
#   54445,
#   57560,
#   56070,
#   41681,
#   53590,
#   50827,
#   46723,
#   45667,
#   36539,
#   55967,
#   55914,
#   58002,
#   57106,
#   38176,
#   54809,
#   38951,
#   38293,
#   75909,
#   38462,
#   38315,
#   52995,
#   52994,
#   53005,
#   53422,
#   671014,
#   670965,
#   73158,
#   70582,
#   75747,
#   671023,
#   74813,
#   53408,
#   53203,
#   53007,
#   53200,
#   53457,
#   53231,
#   53416,
#   53001,
#   53234,
#   53414,
#   53006,
#   53410,
#   53002,
#   53176,
#   671016,
#   670994,
#   54540,
#   53419,
#   53221,
#   761386,
#   53439,
#   671056,
#   53456,
#   53010,
#   53219,
#   52990,
#   53446,
#   53241,
#   53187,
#   53167,
#   53178,
#   53179,
#   670961,
#   72585,
#   671024,
#   50486,
#   55802,
#   53427,
#   53165,
#   53429,
#   53175,
#   40507,
#   43247,
#   74421,
#   53157,
#   53190,
#   53172,
#   670891,
#   39901,
#   670920,
#   53449,
#   670943,
#   78227,
#   56128,
#   667348,
#   45640,
#   54576,
#   54567,
#   670908,
#   53660,
#   73352,
#   670916,
#   670949,
#   670883,
#   670910,
#   671036,
#   670989,
#   671042,
#   49151,
#   670894,
#   670947,
#   670882,
#   670938,
#   671039,
#   662782,
#   53458,
#   670917,
#   68411,
#   74423,
#   36118,
#   53444,
#   53426,
#   64872,
#   670974,
#   48950,
#   670968,
#   671035,
#   53230,
#   45358,
#   76091,
#   69670,
#   77871,
#   76458,
#   72747,
#   45359,
#   39902,
#   54184,
#   53453,
#   670897,
#   76769,
#   65584,
#   44292,
#   39111,
#   670995,
#   40487,
#   73355,
#   670921,
#   671007,
#   671005,
#   73358,
#   670993,
#   53424,
#   36315,
#   53228,
#   670981,
#   38926,
#   53454,
#   41483,
#   53465,
#   670950,
#   670942,
#   54774,
#   671026,
#   670928,
#   670979,
#   671046,
#   671055,
#   671050,
#   77657,
#   74424,
#   69860,
#   53443,
#   53466,
#   671008,
#   56901,
#   671028,
#   671027,
#   53409,
#   670915,
#   78670,
#   53401,
#   53245,
#   765654,
#   48556,
#   48773,
#   48728,
#   48541,
#   48099,
#   47975,
#   48801,
#   47974,
#   47973,
#   45556,
#   45559,
#   44440,
#   45553,
#   44441,
#   45560,
#   45558,
#   45557,
#   45561,
#   52444,
#   52357,
#   52479,
#   52478,
#   52355,
#   56856,
#   56855,
#   53469,
#   56854,
#   46000,
#   45823,
#   45839,
#   45972,
#   45828,
#   45943,
#   45825,
#   45824,
#   45904,
#   45881,
#   45977,
#   45926,
#   45936,
#   45949,
#   45966,
#   46010,
#   45922,
#   45827,
#   46002,
#   45988,
#   45871,
#   45838,
#   45959,
#   45918,
#   45853,
#   45993,
#   45861,
#   45826,
#   45892,
#   46005,
#   46983,
#   47100,
#   46600,
#   47004,
#   46498,
#   46482,
#   46114,
#   47005,
#   46971,
#   47001,
#   47097,
#   47000,
#   46510,
#   46975,
#   46488,
#   47067,
#   47096,
#   47066,
#   46974,
#   46486,
#   46500,
#   47048,
#   47087,
#   46686,
#   47038,
#   46496,
#   46696,
#   46107,
#   47003,
#   47046,
#   46972,
#   46576,
#   46487,
#   46698,
#   46511,
#   46990,
#   46103,
#   46848,
#   46090,
#   47090,
#   47002,
#   47095,
#   62382,
#   63003,
#   63006,
#   62993,
#   62933,
#   62938,
#   62992,
#   63015,
#   62911,
#   62996,
#   62998,
#   62913,
#   62561,
#   63020,
#   62934,
#   62916,
#   62936,
#   63007,
#   62941,
#   62940,
#   62924,
#   47140,
#   47397,
#   47331,
#   47327,
#   47214,
#   47150,
#   47261,
#   47141,
#   47180,
#   47304,
#   47146,
#   47181,
#   47353,
#   47474,
#   47260,
#   47385,
#   47268,
#   47392,
#   47202,
#   47262,
#   47222,
#   47415,
#   47224,
#   47182,
#   47151,
#   47193,
#   47197,
#   47414,
#   47416,
#   47391,
#   47444,
#   47183,
#   47228,
#   47119,
#   47168,
#   47363,
#   47637,
#   47658,
#   47544,
#   47968,
#   47477,
#   47543,
#   47478,
#   47542,
#   47902,
#   47846,
#   47594,
#   47721,
#   47967,
#   47948,
#   47541,
#   47959,
#   47661,
#   47568,
#   47830,
#   47498,
#   47940,
#   47869,
#   47525,
#   47870,
#   47593,
#   47915,
#   47695,
#   47928,
#   47479,
#   47499,
#   47537,
#   47785,
#   47969,
#   47719,
#   47618,
#   62912,
#   63004,
#   62919,
#   62999,
#   62917,
#   62943,
#   62914,
#   62942,
#   62995,
#   63040,
#   63047,
#   63034,
#   63048,
#   63049,
#   63042,
#   63033,
#   63054,
#   63046,
#   63041,
#   63036,
#   63044,
#   63057,
#   62937,
#   62918,
#   62994,
#   62910,
#   62939,
#   63002,
#   76574,
#   41774,
#   46977,
#   47572,
#   47636,
#   50217,
#   52352,
#   52349,
#   52345,
#   52344,
#   48871,
#   44936,
#   44922,
#   44937,
#   44448,
#   45554,
#   45555,
#   46968,
#   48870,
#   ...]}

# %% [markdown]
# Выполните поисковый запрос для департамента "Asian art" (departmentId = 6) с тегом "cat" и запишите id объектов в cat_ids. Используйте цикл из шага 4, чтобы получить данные о первой 1000 объектов из списка.

# %% [markdown]
# В качестве ответа укажите, в каком периоде (period) было выполнено наибольшее количество работ, представленных в музее?

# %% [markdown]
# - Timurid period (1370–1507)
# - __Edo period (1615–1868)__
# - Tang dynasty (618–907)
# - Meiji period (1868–1912)
# - Период чаще всего не указан

# %%
cats_id = cats["objectIDs"]

# %%
len(cats_id)
# Out:
# 3056

# %%
data_frame = pd.DataFrame()
for i in cats_id[:1000]:
    try:
        r_test = requests.get(f'https://collectionapi.metmuseum.org/public/collection/v1/objects/{i}')
        obj_test = r_test.json()
        dframe = pd.DataFrame({'objectID': obj_test['objectID'], 'title': obj_test['title'],
                               'artistDisplayName': obj_test['artistDisplayName'], 'department': obj_test['department'],
                               'objectBeginDate': obj_test['objectBeginDate'], 'objectEndDate': obj_test['objectEndDate'],
                               'period': obj_test['period'], 'objectName': obj_test['objectName'], 'culture': obj_test['culture']}, index=[0])
        data_frame = data_frame.append(dframe)
    except:
        continue

# %%
data_frame
# Out:
#     objectID                                              title  \
# 0      49698                                                Cat
# 0      49470                                                Cat
# 0      53222                                           Musk Cat
# 0      36221                                                Cat
# 0      60873                                      Head ornament
# ..       ...                                                ...
# 0      44448                                       Square Flask
# 0      45554  Water Jar with Design of the Seven Sages in th...
# 0      45555  Water Jar (Mizusashi) with the Seven Sages of ...
# 0      46968                                       Square Flask
# 0      48870                 Chinese Child Playing a Game of Go
#
#    artistDisplayName department  objectBeginDate  objectEndDate  \
# 0      Zhang Yuguang  Asian Art             1900           1968
# 0            Wang Li  Asian Art             1813           1879
# 0         Uto Gyoshi  Asian Art             1550           1599
# 0           Wang Yun  Asian Art             1900           1933
# 0                     Asian Art              960           1279
# ..               ...        ...              ...            ...
# 0                     Asian Art             1700           1799
# 0                     Asian Art             1767           1799
# 0                     Asian Art             1767           1799
# 0                     Asian Art             1700           1799
# 0                     Asian Art             1767           1799
#
#                               period                            objectName  \
# 0                                     Folding fan mounted as an album leaf
# 0           Qing dynasty (1644–1911)                        Hanging scroll
# 0       Muromachi period (1392–1573)                        Hanging scroll
# 0                                                           Hanging scroll
# 0   Song dynasty (960–1279) or later                         Head ornament
# ..                               ...                                   ...
# 0             Edo period (1615–1868)                          Square flask
# 0             Edo period (1615–1868)                                   Jar
# 0             Edo period (1615–1868)                             Water jar
# 0             Edo period (1615–1868)                          Square flask
# 0             Edo period (1615–1868)                               Ceramic
#
#    culture
# 0    China
# 0    China
# 0    Japan
# 0    China
# 0    China
# ..     ...
# 0    Japan
# 0    Japan
# 0    Japan
# 0    Japan
# 0    Japan
#
# [1000 rows x 9 columns]

# %%
data_frame.period.value_counts()
# Out:
# Edo period (1615–1868)                                          440
#                                                                 122
# Qing dynasty (1644–1911)                                         45
# Eastern Javanese period                                          29
# Muromachi period (1392–1573)                                     29
#                                                                ...
# Malla period                                                      1
# Ming dynasty (1368–1644), Jiajing mark and period (1522–66)       1
# Qing dynasty (1644–1911), Kangxi mark and period (1662–1722)      1
# Qing dynasty (1644–1911), Yongzheng period (1723–35)              1
# late Edo (1615–1868)-early Meiji period (1868–1912)               1
# Name: period, Length: 97, dtype: int64
